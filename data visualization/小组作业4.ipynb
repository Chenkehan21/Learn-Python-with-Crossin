# %%
import pandas as pd
from pyecharts.charts import Bar
from pyecharts.charts import Pie
from pyecharts import options as opts

# %% [markdown]
# # 读取 Task_4_lianjia_sale.csv 数据(阅读参考文章 2、3)，利用 groupby 函数，以【区域】字段进行 groupby， 同时结合 agg 聚合函数统计各个区域平均房价; 将统计所得平均房价命名为【区域平均价格】列 (阅读参考文章 4、5)并将数据从小到大按顺序排列(提示:df.sort_values(by = “ ”) (阅读参考文章 6));最后展示所得前 5 行数据 (将所得的 DataFrame 命名为 df_avg);

# %%
with open("data/Task_4_lianjia_sale.csv", encoding='utf-8') as f:
    lianjia_sale = pd.read_csv(f)
lianjia_sale.head(10)
# Out:
#                             房型     价格                 小区   面积（㎡）  建造年份     户型  \
# 0     大华电梯两房/房型正气/开门南北通/房东诚意出售  76531  大华锦绣华城(十六街区)(公寓)    90.16  2010  2室2厅
# 1  非底楼 满五年唯一 税费少 婚房装修 楼称佳 户型方正  52290               芳雅苑    63.11  1995  2室1厅
# 2  满五唯一+7号线锦绣路+复式房+带阁楼+小区央位+精装  62878               锦博苑    79.52  2007  2室2厅
# 3     13号线陈春路地铁400米中间楼层诚意卖看房方便  45866              鹏海小区    71.95  1997  2室1厅
# 4    朝阳正气一房，采光好，坐看花园，户型方正，看房方便  83942            万邦都市花园    54.80  2004  1室1厅
# 5  非顶楼 一梯两户 双南两房 厅窗户大 房改售房增值税0  47774              由由一村    68.03  1994  2室1厅
# 6       稀有浅色系4房 视野开阔 我有钥匙 业主急售  94725             浦东星河湾   242.81  2010  4室3厅
# 7    浦东星河湾泳池全景房+视野开阔+优选房源+诚意出售  82972             浦东星河湾   301.31  2010  4室3厅
# 8   花木街道+满两年+精装修+中间楼层+双轨交通业主诚售  48000              由由一村    60.00  1995  2室1厅
# 9     新上房源，边套全明，看房方便，比邻星河湾，近地铁  53642              由由四村    40.64  1997  1室1厅
#
#       朝向  装修类型           楼层  区域
# 0     南    简装    中楼层(共18层)   浦东
# 1     南    精装     低楼层(共6层)   浦东
# 2     南    精装     高楼层(共6层)   浦东
# 3     南    简装     中楼层(共6层)   浦东
# 4     南    简装    中楼层(共11层)   浦东
# 5     南    简装     高楼层(共6层)   浦东
# 6     南    精装    低楼层(共18层)   浦东
# 7     南    精装    中楼层(共17层)   浦东
# 8   南 北    精装     中楼层(共6层)   浦东
# 9     南    简装     中楼层(共6层)   浦东

# %%
df_avg = lianjia_sale.groupby(['区域']).价格.agg({'区域平均价格': 'mean'})
formater="{0:.03f}".format
pd.set_option('precision', 2) # control decimal places!!!!!
df_avg.sort_values(by=['区域平均价格']).head()
# Out:
# D:\Anaconda3\install\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#       区域平均价格
# 区域
# 金山  19304.82
# 奉贤  23662.13
# 松江  36461.72
# 嘉定  36587.69
# 青浦  37078.86

# %% [markdown]
# # 利用 Pyecharts 将第(1)问所得数据作条形图(阅读参考文章 7)，图表标题为“上海各区域平均价格”(提示: 最后用 render_notebook()渲染显示出图片);

# %%
locations = list(df_avg.index)
avg_price = [round(x, 2) for x in df_avg['区域平均价格'].values.tolist()] 
# use round() to control the values' decimal places !!!

# %%
bar = (
    Bar()
    .add_xaxis(locations)
    .add_yaxis("price", avg_price)
    .set_global_opts(title_opts={"text": "上海各区域平均价格"})
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9f607fb006664136b49ef58d81d8f6e9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9f607fb006664136b49ef58d81d8f6e9 = echarts.init(
#                     document.getElementById('9f607fb006664136b49ef58d81d8f6e9'), 'white', {renderer: 'canvas'});
#                 var option_9f607fb006664136b49ef58d81d8f6e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "price",
#             "data": [
#                 36587.69,
#                 23662.13,
#                 42577.8,
#                 75395.94,
#                 57943.13,
#                 62726.67,
#                 36461.72,
#                 55413.06,
#                 66165.35,
#                 19304.82,
#                 72099.62,
#                 49080.59,
#                 37078.86,
#                 74304.77,
#                 95015.09
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "price"
#             ],
#             "selected": {
#                 "price": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5609\u5b9a",
#                 "\u5949\u8d24",
#                 "\u5b9d\u5c71",
#                 "\u5f90\u6c47",
#                 "\u666e\u9640",
#                 "\u6768\u6d66",
#                 "\u677e\u6c5f",
#                 "\u6d66\u4e1c",
#                 "\u8679\u53e3",
#                 "\u91d1\u5c71",
#                 "\u957f\u5b81",
#                 "\u95f5\u884c",
#                 "\u9752\u6d66",
#                 "\u9759\u5b89",
#                 "\u9ec4\u6d66"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": {
#         "text": "\u4e0a\u6d77\u5404\u533a\u57df\u5e73\u5747\u4ef7\u683c"
#     }
# };
#                 chart_9f607fb006664136b49ef58d81d8f6e9.setOption(option_9f607fb006664136b49ef58d81d8f6e9);
#         });
#     </script>

# %% [markdown]
# # 利用 groupby 函数，以【装修类型】字段进行 groupby，同时结合 agg 聚合函数统计各个区域房源数量; 将统计所得数据命名为【房源数量】列;最后展示所得数据(将所得的 DataFrame 命名为 df_zhuangxiu);

# %%
df_zhuangxiu = lianjia_sale.groupby('装修类型').区域.agg({'房源数量': 'count'})
df_zhuangxiu
# Out:
# D:\Anaconda3\install\envs\tensorflow-gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#
#   """Entry point for launching an IPython kernel.
#        房源数量
# 装修类型
#  其他    5414
#  毛坯    5357
#  简装   22819
#  精装   32425

# %% [markdown]
# # 利用 Pyecharts 将第(3)问所得数据作饼图(阅读参考文章 7、8)，图表标题为“装修类型占比情况”(提示: v1=["啤酒","可乐","雪碧","咖啡","奶茶"] v2=[30,19,21,12,18]，a = [list(z) for z in zip(v1,v2)]， 则生成 v1 与 v2 一一对应的数据)。

# %%
pie = (
    Pie()
    .add("", [list(x) for x in zip(list(df_zhuangxiu.index), df_zhuangxiu['房源数量'].values.tolist())])
    .set_global_opts(title_opts=opts.TitleOpts(title='装修类型占比情况'))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}"))
)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="11c090213c104063bfbceb49d129bb0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_11c090213c104063bfbceb49d129bb0f = echarts.init(
#                     document.getElementById('11c090213c104063bfbceb49d129bb0f'), 'white', {renderer: 'canvas'});
#                 var option_11c090213c104063bfbceb49d129bb0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": " \u5176\u4ed6 ",
#                     "value": 5414
#                 },
#                 {
#                     "name": " \u6bdb\u576f ",
#                     "value": 5357
#                 },
#                 {
#                     "name": " \u7b80\u88c5 ",
#                     "value": 22819
#                 },
#                 {
#                     "name": " \u7cbe\u88c5 ",
#                     "value": 32425
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}:{c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 " \u5176\u4ed6 ",
#                 " \u6bdb\u576f ",
#                 " \u7b80\u88c5 ",
#                 " \u7cbe\u88c5 "
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u88c5\u4fee\u7c7b\u578b\u5360\u6bd4\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_11c090213c104063bfbceb49d129bb0f.setOption(option_11c090213c104063bfbceb49d129bb0f);
#         });
#     </script>
