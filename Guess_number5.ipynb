# %%
import requests
   
def initialize():
    global name
    name = input("Please tell me your name: ")
    try:
        with open("record.txt", 'r+') as f:
            f.seek(0)
            info = [m.strip().split('\t') for m in f.readlines()]
            f.seek(0)
            info2 = f.read()
    except:
        print("open failed!")
            
    global played_rounds, played_least_times, played_ave_times, played_total_guess_times    
    for i in info:
        if name in i:
            played_rounds = int(i[i.index(name) + 1])
            played_least_times = int(i[i.index(name) + 2])
            played_ave_times = float(i[i.index(name) + 3])
            played_total_guess_times = played_rounds * played_ave_times
            print("Hi %s, you have played %s rounds, you guessed the answer in at least %s times, "\
                  "you guessed the answer on average %s times each round."
                  % (name, i[i.index(name) + 1], i[i.index(name) + 2], i[i.index(name) + 3]))
            print("Let's start!", '\n')
    if name not in info2:
        try:
            with open("record.txt", 'a') as f:
                f.seek(2)
                f.write("%s\t0\t0\t0\n" % name)
        except:
            print("write failed!")
        print("%s you have played 0 round, you guessed the answer in at least 0 time, "\
        "you guess the answer on average 0 time each round." % name)
        print("Let's start!", '\n')

    print("You need to guess the number I think." + '\n' + "hint: It's an integer from 1 to 100")
    print('\n' + "Round1")

def guess_and_check():
    global guess_number
    global Bingo
    num_type = False
    while num_type == False:
        try:
            guess_number = int(input("Please enter your answer: "))
        except:    
            print("You must enter an integer!!!")
        else:
            if type(guess_number) == int:
                Bingo = False
                break

def compare(result, count):
    guess_and_check()
    if guess_number < result:
        print("Too small!")
        return False
    elif guess_number > result:
        print("Too big!")
        return False
    else:
        print("Bingo!!!")
        print("You guessed %d times" % count + '\n')
        num.append(count)
        return replay()  # there must be "return replay()"!!! if omit "return", it doesn't work!!!
        
def replay():
    global Round
    global count
    global result
    restart = input("Do you want to replay? (Press 'Y' to continue, press any other key to quit): ")
    if restart == "Y" or restart == "y":
        url = "https://python666.cn/cls/number/guess/"
        req = requests.get(url)
        req.encoding = "gbk"
        result = eval(req.text)
        Round += 1
        print('\n' + "Round%d" % Round)
        count = 0
        return False
    else:
        average = sum(num) / len(num)
        print('\n' + "THIS TIME: you played %d rounds, you guessed the answer in at least %d times, "\
              "you need to guess %.2f times per round"
              % (Round, min(num), average))
        print('\n' + "TOTAL: you have played %d rounds, you guessed the answer in at least %d times, "\
              "you need to guess %.2f times per round"
              % (Round + played_rounds, min(min(num), played_least_times),
                         (sum(num) + played_total_guess_times) / (Round + played_rounds)))
        update()
        return True

def update():
    try:
        with open("record.txt", 'r+') as f:
            f.seek(0)
            data = ''
            for line in f.readlines():
                if line.find("%s" % name) == 0:
                    line = "%s\t%d\t%d\t%.2f" % (name, Round + played_rounds, min(min(num), played_least_times),
                     (sum(num) + played_total_guess_times) / (Round + played_rounds)) + '\n'
                    print(line)
                data += line
        with open("record.txt", "r+") as f:
            f.writelines(data)
    except:
        print("open failed!")
    
def play():
    global result
    url = "https://python666.cn/cls/number/guess/"
    req = requests.get(url)
    req.encoding = "gbk"
    result = eval(req.text)
    global count
    initialize()
    while not compare(result, count):
        count += 1

count = 1
Round = 1
num = []
play()
# Out:
# Please tell me your name: ckh
# Hi ckh, you have played 3 rounds, you guessed the answer in at least 7 times, you guessed the answer on average 8.33 times each round.
# Let's start!
#
# You need to guess the number I think.
# hint: It's an integer from 1 to 100
#
# Round1
# Please enter your answer: 50
# Too small!
# Please enter your answer: 75
# Too big!
# Please enter your answer: 57
# Too small!
# Please enter your answer: 63
# Too small!
# Please enter your answer: 69
# Too big!
# Please enter your answer: 66
# Too big!
# Please enter your answer: 64
# Bingo!!!
# You guessed 7 times
#
# Do you want to replay? (Press 'Y' to continue, press any other key to quit): n
#
# THIS TIME: you played 1 rounds, you guessed the answer in at least 7 times, you need to guess 7.00 times per round
#
# TOTAL: you have played 4 rounds, you guessed the answer in at least 7 times, you need to guess 8.00 times per round
# ckh	4	7	8.00
